# %% [markdown]
# # Tokenisation

# %%
corpus = """Hello, I'm. am Krishna Singha.
I like AI, ML and NLP.
"""

print(corpus)
# Out:
# Hello, I'm. am Krishna Singha.
# I like AI, ML and NLP.

# %% [markdown]
# #### 1. Corpus(Paragraph) -> Documents(Sentences)

# %%
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello, I'm.
# am Krishna Singha.
# I like AI, ML and NLP.

# %% [markdown]
# #### 2. Corpus(Paragraph) -> Words

# %%
from nltk.tokenize import word_tokenize

# %%
words = word_tokenize(corpus)

# %%
for word in words:
    print(word)

# words
# Out:
# Hello
# ,
# I
# 'm
# .
# am
# Krishna
# Singha
# .
# I
# like
# AI
# ,
# ML
# and
# NLP
# .

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'I',
#  "'",
#  'm',
#  '.',
#  'am',
#  'Krishna',
#  'Singha',
#  '.',
#  'I',
#  'like',
#  'AI',
#  ',',
#  'ML',
#  'and',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
TreebankWordTokenizer().tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  "I'm.",
#  'am',
#  'Krishna',
#  'Singha.',
#  'I',
#  'like',
#  'AI',
#  ',',
#  'ML',
#  'and',
#  'NLP',
#  '.']

# %% [markdown]
# #### 3. Documents(Sentences) -> Words

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', ',', 'I', "'m", '.']
# ['am', 'Krishna', 'Singha', '.']
# ['I', 'like', 'AI', ',', 'ML', 'and', 'NLP', '.']

# %%
for sentence in documents:
    print(wordpunct_tokenize(sentence))
# Out:
# ['Hello', ',', 'I', "'", 'm', '.']
# ['am', 'Krishna', 'Singha', '.']
# ['I', 'like', 'AI', ',', 'ML', 'and', 'NLP', '.']

# %%
tokenizer = TreebankWordTokenizer()

for sentence in documents:
    print(tokenizer.tokenize(sentence))
# Out:
# ['Hello', ',', 'I', "'m", 'am', 'Krishna', 'Singha', '.']
# ['I', 'like', 'AI', ',', 'ML', 'and', 'NLP', '.']
